# %%
import os

class Station: 
    def __init__(self,name):
        self.name = name
        self.neighbor = list()

    def add_connection(self,another_station):
        self.neighbor.append(another_station)

        another_station.neighbor.append(self)
def bfs(start, goal):
    previous = {}
    que = deque()
    current = None
    
    previous[start] = None
    que.append(start)
    
    if 
    
        
stations = dict()
in_file = open('stations.txt',encoding='UTF-8').readlines()
    
for i in in_file:
    prev=None
    name = i.strip().split('-')
    for j in name:
        if j.strip() not in stations.keys():
            state = Station(j.strip())
            stations[j.strip()] = state
        else:
            state = stations[j.strip()]
        if prev != None:
            state.add_connection(prev)
        
        prev = state

# %%
print(stations)
# Out:
# {'소요산': <__main__.Station object at 0x000001F3572F0A58>, '동두천': <__main__.Station object at 0x000001F3572E7198>, '보산': <__main__.Station object at 0x000001F3572E7160>, '동두천중앙': <__main__.Station object at 0x000001F3572E72B0>, '지행': <__main__.Station object at 0x000001F3572E72E8>, '덕정': <__main__.Station object at 0x000001F3572E7320>, '덕계': <__main__.Station object at 0x000001F3572E7358>, '양주': <__main__.Station object at 0x000001F3572E7390>, '녹양': <__main__.Station object at 0x000001F3572E73C8>, '가능': <__main__.Station object at 0x000001F3572E7400>, '의정부': <__main__.Station object at 0x000001F3572E7438>, '회룡': <__main__.Station object at 0x000001F3572E7470>, '망월사': <__main__.Station object at 0x000001F3572E74A8>, '도봉산': <__main__.Station object at 0x000001F3572E74E0>, '도봉': <__main__.Station object at 0x000001F3572E7518>, '방학': <__main__.Station object at 0x000001F3572E7550>, '창동': <__main__.Station object at 0x000001F3572E7588>, '녹천': <__main__.Station object at 0x000001F3572E75C0>,
# ...
